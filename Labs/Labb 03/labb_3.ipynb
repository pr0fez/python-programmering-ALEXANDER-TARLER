# %%
import matplotlib.pyplot as plt
import numpy as np

unlabelled_data = "./unlabelled_data.csv"  

with open(unlabelled_data, "r") as f_read:
    for line in f_read:
        x, y = map(float, line.split(","))
        plt.scatter(x, y)


            



plt.show()
# Out:
# -1.885907518189583,-1.997407599218205
#
# 2.0903622010733187,2.5624899544171473
#
# -2.9282206832334725,0.08238727568546045
#
# 2.895800158650832,2.4354575617849648
#
# -2.3589641484790733,-1.0384290490456443
#
# -2.932220395566431,-1.7663127885080874
#
# 1.74903383418092,3.169329803364248
#
# 2.3129230208512994,0.49425588500276785
#
# 2.791891489626311,3.8567073257360334
#
# 2.980067730688754,2.5056818879726044
#
# 0.7024883052821786,1.2321833124091244
#
# -1.6970685457243755,-2.5737245528039745
#
# 1.421849654822276,4.2624358053443085
#
# 4.198374704780727,1.870410371844826
#
# -1.6132858469887672,-2.1482643011711846
#
# 1.0289434595917375,3.0631528533329035
#
# -3.430233207020642,-0.17854123414564604
#
# -1.7483639749523658,-2.655119754605124
#
# -2.329671887837512,-1.6528874284882533
#
# -2.051791281554,-3.152970297830623
#
# -1.2523403767979806,-2.169938529963427
#
# -3.1776204293825945,-2.152379485021293
#
# -1.850277498278518,-2.9143166251044086
#
# ...
